# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter, DateLocator
import numpy as np
import seaborn as sb

# handling date time conversion between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# using a white grid plot background from seaborn
sb.set(font_scale=1.5, style='whitegrid')

# importing the csv file of the data I am working with 
weight_data = pd.read_csv("Workout Split, Calories, Weight (2022) - Bodyweight by day (2_4_22 - 2_1_23).csv",
                            parse_dates=['Unnamed: 0'],
                            index_col=['Unnamed: 0'],
                            na_values=['999.99'])

# creating a pandas dataframe, so I can work with the csv file
df = pd.DataFrame(data=weight_data)

# getting the rows from index 0 to 332 which is the first of the year to the end of the year, and getting the first four columns (the only columns that have meaningful data)
df1 = df.iloc[1:332, [0,1,2]]

# getting the rows for each month, and getting the first three columns (the only columns that have meaningful data)
df2 = df1.iloc[0:25, [0,1,2]] # feb
df3 = df1.iloc[25:56, [0,1,2]] # march 
df4 = df1.iloc[56:86, [0,1,2]] # april
df5 = df1.iloc[86:117, [0,1,2]] # may 
df6 = df1.iloc[117:147, [0,1,2]] # june 
df7 = df1.iloc[147:178, [0,1,2]] # july 
df8 = df1.iloc[178:209, [0,1,2]] # august 
df9 = df1.iloc[209:239, [0,1,2]] # september 
df10 = df1.iloc[239:270, [0,1,2]] # october 
df11 = df1.iloc[270:300, [0,1,2]] # november 
df12 = df1.iloc[300:331, [0,1,2]] # december 

# displaying the plot in the notebook window
# %matplotlib inline

# FULL YEAR
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df1['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df1.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight 2022')
# setting the number of ticks by month 
plt.xticks(['2/4', '3/4', '4/4', '5/4', '6/4', '7/4', '8/4', '9/4', '10/4', '11/4', '12/4'])

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df1.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
year_std_dev = np.std(wd)
year_mean = np.mean(wd)
year_median = np.median(wd)
print('2022 standard deviation:',year_std_dev)
print('2022 mean:',year_mean)
print('2022 median:',year_median)

# ----------------------------------------------------------------
# FEB
# configuring the figure and plot space
fig, lx = plt.subplots( figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df2['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes' values
lx.plot(df2.index.values, wd)

# defining what the labels will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight February 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df2.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
feb_std_dev = np.std(wd)
feb_mean = np.mean(wd)
feb_median = np.median(wd)
print('\nFebruary standard deviation:',feb_std_dev)
print('February mean:',feb_mean)
print('February median:',feb_median)


# ----------------------------------------------------------------
# MARCH
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df3['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df3.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight March 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df3.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
march_std_dev = np.std(wd)
march_mean = np.mean(wd)
march_median = np.median(wd)
print('\nMarch standard deviation:',march_std_dev)
print('March mean:',march_mean)
print('March median:',march_median)

# ----------------------------------------------------------------
# APRIL
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df4['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df4.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight April 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df4.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
april_std_dev = np.std(wd)
april_mean = np.mean(wd)
april_median = np.median(wd)
print('\nApril standard deviation:',april_std_dev)
print('April mean:',april_mean)
print('April median:',april_median)

# ----------------------------------------------------------------
# MAY
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df5['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df5.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight May 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df5.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
may_std_dev = np.std(wd)
may_mean = np.mean(wd)
may_median = np.median(wd)
print('\nMay standard deviation:',may_std_dev)
print('May mean:',may_mean)
print('May median:',may_median)

# ----------------------------------------------------------------
# JUNE
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df6['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df6.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight June 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df6.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
june_std_dev = np.std(wd)
june_mean = np.mean(wd)
june_median = np.median(wd)
print('\nJune standard deviation:',june_std_dev)
print('June mean:',june_mean)
print('June median:',june_median)

# ----------------------------------------------------------------
# JULY
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df7['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df7.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight July 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df7.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
july_std_dev = np.std(wd)
july_mean = np.mean(wd)
july_median = np.median(wd)
print('\nJuly standard deviation:',july_std_dev)
print('July mean:',july_mean)
print('July median:',july_median)

# ----------------------------------------------------------------
# AUGUST
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df8['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df8.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight August 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df8.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
august_std_dev = np.std(wd)
august_mean = np.mean(wd)
august_median = np.median(wd)
print('\nAugust standard deviation:',august_std_dev)
print('August mean:',august_mean)
print('August median:',august_median)

# ----------------------------------------------------------------
# SEPTEMBER
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df9['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df9.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight September 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df9.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
sept_std_dev = np.std(wd)
sept_mean = np.mean(wd)
sept_median = np.median(wd)
print('\nSeptember standard deviation:',sept_std_dev)
print('September mean:',sept_mean)
print('September median:',sept_median)

# ----------------------------------------------------------------
# OCTOBER
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df10['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df10.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight October 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df10.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
oct_std_dev = np.std(wd)
oct_mean = np.mean(wd)
oct_median = np.median(wd)
print('\nOctober standard deviation:',oct_std_dev)
print('October mean:',oct_mean)
print('October median:',oct_median)

# ----------------------------------------------------------------
# NOVEMBER
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df11['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df11.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight Novemeber 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df11.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
nov_std_dev = np.std(wd)
nov_mean = np.mean(wd)
nov_median = np.median(wd)
print('\nNovember standard deviation:',nov_std_dev)
print('November mean:',nov_mean)
print('November median:',nov_median)
# ----------------------------------------------------------------

# DECEMBER
# configuring the figure and plot space
fig, lx = plt.subplots(figsize=(30,10))

# converting the Series into str so the data can be plotted
wd = df12['Unnamed: 1']
wd = wd.astype(float)

# adding the x and y axes 
lx.plot(df12.index.values, wd)

# defining what the values for the axes will be 
lx.set(xlabel='Day', ylabel='Weight', title='Daily Weight December 2022')

# adding the trendline to the plot
x = np.array([x for x in range(0,len(df12.index.values))]) # creating a np array for the x values (returning the x index)
y = np.array([wd[y] for y in range(0,len(wd))]) # creating a np array for the y values (return the weight for each x index)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
lx.plot(x,p(x), linestyle='dashed')

# finding the variance of the weight over the month
dec_std_dev = np.std(wd)
dec_mean = np.mean(wd)
dec_median = np.median(wd)
print('\nDecember standard deviation:',dec_std_dev)
print('December mean:',dec_mean)
print('December median:',dec_median)


# ----------------------------------------
# getting nparrays of omonthly std_devs, means, mdeians
monthly_std_dev = np.array([feb_std_dev, march_std_dev, april_std_dev, may_std_dev, june_std_dev, july_std_dev,
                             august_std_dev, sept_std_dev, oct_std_dev, nov_std_dev, dec_std_dev])
monthly_mean = np.array([feb_mean, march_mean, april_mean, may_mean, june_mean, july_mean,
                             august_mean, sept_mean, oct_mean, nov_mean, dec_mean])
monthly_median = np.array([feb_median, march_median, april_median, may_median, june_median, july_median,
                             august_median, sept_median, oct_median, nov_median, dec_median])
# averages over the enitre year
avg_std_dev = np.average(monthly_std_dev)
avg_mean = np.average(monthly_mean)
mean_mean = np.mean(monthly_mean)
avg_median = np.average(monthly_median)
print("\nAverage of monthly standard deviations:",avg_std_dev)
print("Average of monthly means:",avg_mean)
print("Average of monthly medinas:",avg_median)
print("Mean of monthly mean:",mean_mean)
# Out:
# 2022 standard deviation: 5.208296974222234
# 2022 mean: 158.07220543806648
# 2022 median: 157.0
#
# February standard deviation: 1.5814120272718317
# February mean: 164.25599999999997
# February median: 164.2
#
# March standard deviation: 1.18003686074458
# March mean: 165.90967741935484
# March median: 165.6
#
# April standard deviation: 2.6430390756770037
# April mean: 165.36333333333332
# April median: 166.1
#
# May standard deviation: 3.118952837958765
# May mean: 154.07096774193548
# May median: 153.4
#
# June standard deviation: 2.0444939607530177
# June mean: 151.99333333333334
# June median: 152.2
#
# July standard deviation: 1.5373531587281475
# July mean: 155.70967741935488
# July median: 155.8
#
# August standard deviation: 2.0653022696788197
# August mean: 159.50322580645164
# August median: 159.8
#
# September standard deviation: 1.5736157938539725
# September mean: 160.12
# September median: 160.0
#
# October standard deviation: 1.686353379669822
# ...
